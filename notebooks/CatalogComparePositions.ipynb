# %%
from glob import glob
from astroquery.mast import Mast, Observations
import os
import shutil
import pyavm
import numpy as np
import PIL
import json
import requests
import asdf
import regions
from astropy import log
from astropy.io import ascii, fits
from astropy.wcs import WCS
from astropy import wcs
from astropy.coordinates import SkyCoord
from astropy.utils.data import download_file
from astropy.visualization import ImageNormalize, ManualInterval, LogStretch, LinearStretch
from astropy.visualization import simple_norm
import matplotlib.pyplot as plt
import matplotlib as mpl
from astropy.table import Table
from astropy.nddata import Cutout2D
import astropy.units as u

# %%
basepath = '/orange/adamginsburg/jwst/cloudc/'

# %%
ref_tbl = Table.read(f'{basepath}/catalogs/crowdsource_based_nircam-f405n_reference_astrometric_catalog_truncated10000.ecsv')
crds_ref = ref_tbl['skycoord']

# %%
vvvcat = Table.read('/orange/adamginsburg/jwst/cloudc/catalogs/jw02221-o002_t001_nircam_clear-f405n-merged_vvvcat.fits')
crds_vvv = SkyCoord(vvvcat['RAJ2000'].quantity, vvvcat['DEJ2000'].quantity, frame='fk5')

# %%
cd /orange/adamginsburg/jwst/cloudc/analysis/
# Out:
# /blue/adamginsburg/adamginsburg/jwst/cloudc/code/brick-jwst-2221/analysis

# %%
# %run selections.py
# Out:
# /blue/adamginsburg/adamginsburg/jwst/cloudc/code/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.CircularAperture` is a deprecated alias for `photutils.aperture.CircularAperture` and will be removed in the future. Instead, please use `from photutils.aperture import CircularAperture` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# /blue/adamginsburg/adamginsburg/jwst/cloudc/code/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.EPSFBuilder` is a deprecated alias for `photutils.psf.EPSFBuilder` and will be removed in the future. Instead, please use `from photutils.psf import EPSFBuilder` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# /blue/adamginsburg/adamginsburg/jwst/cloudc/code/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.find_peaks` is a deprecated alias for `photutils.detection.find_peaks` and will be removed in the future. Instead, please use `from photutils.detection import find_peaks` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# /blue/adamginsburg/adamginsburg/jwst/cloudc/code/brick-jwst-2221/analysis/selections.py:23: DeprecationWarning: `photutils.CircularAnnulus` is a deprecated alias for `photutils.aperture.CircularAnnulus` and will be removed in the future. Instead, please use `from photutils.aperture import CircularAnnulus` to silence this warning.
#   from photutils import CircularAperture, EPSFBuilder, find_peaks, CircularAnnulus
# Selecting module merged
#
# NRCA
# 3798 saturated in near_saturated_f212n_f212n
# 528 saturated in near_saturated_f466n_f466n
# 1382 saturated in near_saturated_f405n_f405n
# 3317 saturated in near_saturated_f187n_f187n
# 5742 saturated in near_saturated_f182m_f182m
# 11128 near saturated out of 568994.  That leaves 557866 not near unsaturated
# 225 saturated in replaced_saturated_f212n
# 53 saturated in replaced_saturated_f466n
# 147 saturated in replaced_saturated_f405n
# 413 saturated in replaced_saturated_f187n
# 517 saturated in replaced_saturated_f182m
# 1252 saturated out of 568994.  That leaves 567742 unsaturated
# Filter f410m has qf=117890, spread=99442, fracflux=10178 ok, totaling 9965.  There are 568994 total, of which 470886 are masked and 98108 are unmasked. qfmasksum=450489, inverse=118505.
# Filter f212n has qf=370798, spread=371805, fracflux=238730 ok, totaling 238176.  There are 568994 total, of which 197272 are masked and 371722 are unmasked. qfmasksum=197099, inverse=371895.
# Filter f466n has qf=243085, spread=243399, fracflux=83779 ok, totaling 83647.  There are 568994 total, of which 325707 are masked and 243287 are unmasked. qfmasksum=325554, inverse=243440.
# Filter f405n has qf=314157, spread=314412, fracflux=61614 ok, totaling 61515.  There are 568994 total, of which 254719 are masked and 314275 are unmasked. qfmasksum=254527, inverse=314467.
# Filter f187n has qf=297239, spread=298418, fracflux=204753 ok, totaling 204274.  There are 568994 total, of which 270295 are masked and 298699 are unmasked. qfmasksum=270520, inverse=298474.
# Filter f182m has qf=425504, spread=382894, fracflux=18596 ok, totaling 18115.  There are 568994 total, of which 199596 are masked and 369398 are unmasked. qfmasksum=141842, inverse=427152.
# Of 568994 rows, 310 are good in all filters.
# Of 568994 rows, 1033 are good in long filters.
# Of 568994 rows, 8635 are good in short filters.
# Of 568994 rows, 307501 are good in at least one filter.
# QFs: 223133 good short
# QFs: 52502 good long
# Found 116528 of 568994 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Strongly blue [410-466] sources: 23820
# Somewhat blue [410-466] sources: 14048
# 17973 23820 14048 1614 3345 0 35619 0.0
# Negative 405-410 colors: 47742, Nonnegative: 16623
# There are 85 before flagging out any_saturated (there are 21574 any_saturated)
# There are 68 after flagging out any_saturated
# There are 116528 out of 568994 oksep, and 68 all_good & oksep
# Excluding 552440 of 568994
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:68, bad: 568926, len(bad):568994, len(table):568994.
#
# NRCB
# 4118 saturated in near_saturated_f212n_f212n
# 326 saturated in near_saturated_f466n_f466n
# 1353 saturated in near_saturated_f405n_f405n
# 3049 saturated in near_saturated_f187n_f187n
# 7089 saturated in near_saturated_f182m_f182m
# 12920 near saturated out of 592829.  That leaves 579909 not near unsaturated
# 318 saturated in replaced_saturated_f212n
# 43 saturated in replaced_saturated_f466n
# 101 saturated in replaced_saturated_f405n
# 526 saturated in replaced_saturated_f187n
# 491 saturated in replaced_saturated_f182m
# 1564 saturated out of 592829.  That leaves 591265 unsaturated
# Filter f410m has qf=109697, spread=92427, fracflux=11743 ok, totaling 11538.  There are 592829 total, of which 505373 are masked and 87456 are unmasked. qfmasksum=482343, inverse=110486.
# Filter f212n has qf=399173, spread=400188, fracflux=258144 ok, totaling 257537.  There are 592829 total, of which 192648 are masked and 400181 are unmasked. qfmasksum=192515, inverse=400314.
# Filter f466n has qf=282626, spread=282947, fracflux=92414 ok, totaling 92264.  There are 592829 total, of which 310017 are masked and 282812 are unmasked. qfmasksum=309819, inverse=283010.
# Filter f405n has qf=347695, spread=347689, fracflux=47768 ok, totaling 47683.  There are 592829 total, of which 245953 are masked and 346876 are unmasked. qfmasksum=244816, inverse=348013.
# Filter f187n has qf=289886, spread=291179, fracflux=204533 ok, totaling 203913.  There are 592829 total, of which 301239 are masked and 291590 are unmasked. qfmasksum=301618, inverse=291211.
# Filter f182m has qf=437809, spread=432859, fracflux=267774 ok, totaling 267032.  There are 592829 total, of which 176009 are masked and 416820 are unmasked. qfmasksum=153533, inverse=439296.
# Of 592829 rows, 1131 are good in all filters.
# Of 592829 rows, 1345 are good in long filters.
# Of 592829 rows, 110344 are good in short filters.
# Of 592829 rows, 410820 are good in at least one filter.
# QFs: 229901 good short
# QFs: 48686 good long
# Found 108802 of 592829 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Strongly blue [410-466] sources: 18614
# Somewhat blue [410-466] sources: 9641
# 12548 18614 9641 1321 2597 4 33900 0.00011799410029498526
# Negative 405-410 colors: 46249, Nonnegative: 13754
# There are 807 before flagging out any_saturated (there are 26547 any_saturated)
# There are 770 after flagging out any_saturated
# There are 108802 out of 592829 oksep, and 644 all_good & oksep
# Excluding 580844 of 592829
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:644, bad: 592185, len(bad):592829, len(table):592829.
#
# merged-reproject
# 5329 saturated in near_saturated_f212n_f212n
# 1011 saturated in near_saturated_f466n_f466n
# 1933 saturated in near_saturated_f405n_f405n
# 5192 saturated in near_saturated_f187n_f187n
# 9015 saturated in near_saturated_f182m_f182m
# 28901 near saturated out of 773877.  That leaves 744976 not near unsaturated
# 506 saturated in replaced_saturated_f212n
# 124 saturated in replaced_saturated_f466n
# 271 saturated in replaced_saturated_f405n
# 740 saturated in replaced_saturated_f187n
# 886 saturated in replaced_saturated_f182m
# 2349 saturated out of 773877.  That leaves 771528 unsaturated
# Filter f410m has qf=502262, spread=496510, fracflux=87352 ok, totaling 87205.  There are 773877 total, of which 296411 are masked and 477466 are unmasked. qfmasksum=271011, inverse=502866.
# Filter f212n has qf=462888, spread=461474, fracflux=287818 ok, totaling 287643.  There are 773877 total, of which 317742 are masked and 456135 are unmasked. qfmasksum=309802, inverse=464075.
# Filter f466n has qf=354716, spread=351682, fracflux=93814 ok, totaling 93797.  There are 773877 total, of which 430512 are masked and 343365 are unmasked. qfmasksum=419117, inverse=354760.
# Filter f405n has qf=444811, spread=444866, fracflux=83939 ok, totaling 83913.  There are 773877 total, of which 329033 are masked and 444844 are unmasked. qfmasksum=328937, inverse=444940.
# Filter f187n has qf=379642, spread=377527, fracflux=231703 ok, totaling 231614.  There are 773877 total, of which 402012 are masked and 371865 are unmasked. qfmasksum=393758, inverse=380119.
# Filter f182m has qf=605070, spread=606789, fracflux=481599 ok, totaling 480198.  There are 773877 total, of which 179458 are masked and 594419 are unmasked. qfmasksum=164396, inverse=609481.
# Of 773877 rows, 22185 are good in all filters.
# Of 773877 rows, 33159 are good in long filters.
# Of 773877 rows, 174680 are good in short filters.
# Of 773877 rows, 534433 are good in at least one filter.
# QFs: 308554 good short
# QFs: 233963 good long
# Found 167069 of 773877 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Strongly blue [410-466] sources: 11537
# Somewhat blue [410-466] sources: 15158
# 67757 11537 15158 49739 66064 11736 215578 0.054439692361929325
# Negative 405-410 colors: 1788, Nonnegative: 351071
# There are 22137 before flagging out any_saturated (there are 30007 any_saturated)
# There are 21690 after flagging out any_saturated
# There are 167069 out of 773877 oksep, and 21430 all_good & oksep
# Excluding 707331 of 773877
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:21430, bad: 752447, len(bad):773877, len(table):773877.
#
# merged
# 5622 saturated in near_saturated_f212n_f212n
# 662 saturated in near_saturated_f466n_f466n
# 1429 saturated in near_saturated_f405n_f405n
# 5470 saturated in near_saturated_f187n_f187n
# 9063 saturated in near_saturated_f182m_f182m
# 18466 near saturated out of 842660.  That leaves 824194 not near unsaturated
# 595 saturated in replaced_saturated_f212n
# 93 saturated in replaced_saturated_f466n
# 205 saturated in replaced_saturated_f405n
# 856 saturated in replaced_saturated_f187n
# 801 saturated in replaced_saturated_f182m
# 2476 saturated out of 842660.  That leaves 840184 unsaturated
# Filter f410m has qf=145647, spread=122710, fracflux=17852 ok, totaling 17526.  There are 842660 total, of which 733526 are masked and 109134 are unmasked. qfmasksum=696250, inverse=146410.
# Filter f212n has qf=522595, spread=524441, fracflux=333867 ok, totaling 333198.  There are 842660 total, of which 321104 are masked and 521556 are unmasked. qfmasksum=317238, inverse=525422.
# Filter f466n has qf=431154, spread=431500, fracflux=124144 ok, totaling 123977.  There are 842660 total, of which 411451 are masked and 431209 are unmasked. qfmasksum=411063, inverse=431597.
# Filter f405n has qf=471178, spread=467059, fracflux=88240 ok, totaling 88111.  There are 842660 total, of which 395754 are masked and 446906 are unmasked. qfmasksum=370991, inverse=471669.
# Filter f187n has qf=441352, spread=442707, fracflux=296723 ok, totaling 296082.  There are 842660 total, of which 399315 are masked and 443345 are unmasked. qfmasksum=399873, inverse=442787.
# Filter f182m has qf=641760, spread=376645, fracflux=127120 ok, totaling 89810.  There are 842660 total, of which 393198 are masked and 449462 are unmasked. qfmasksum=195272, inverse=647388.
# Of 842660 rows, 476 are good in all filters.
# Of 842660 rows, 2059 are good in long filters.
# Of 842660 rows, 26590 are good in short filters.
# Of 842660 rows, 492926 are good in at least one filter.
# QFs: 347668 good short
# QFs: 64733 good long
# Found 145997 of 842660 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Strongly blue [410-466] sources: 26769
# Somewhat blue [410-466] sources: 15827
# 18318 26769 15827 1204 2388 0 44905 0.0
# Negative 405-410 colors: 64513, Nonnegative: 16256
# There are 294 before flagging out any_saturated (there are 43570 any_saturated)
# There are 277 after flagging out any_saturated
# There are 145997 out of 842660 oksep, and 230 all_good & oksep
# Excluding 825755 of 842660
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:230, bad: 842430, len(bad):842660, len(table):842660.
# 5622 saturated in near_saturated_f212n_f212n
# 662 saturated in near_saturated_f466n_f466n
# 1429 saturated in near_saturated_f405n_f405n
# 5470 saturated in near_saturated_f187n_f187n
# 9063 saturated in near_saturated_f182m_f182m
# 18466 near saturated out of 842660.  That leaves 824194 not near unsaturated
# 595 saturated in replaced_saturated_f212n
# 93 saturated in replaced_saturated_f466n
# 205 saturated in replaced_saturated_f405n
# 856 saturated in replaced_saturated_f187n
# 801 saturated in replaced_saturated_f182m
# 2476 saturated out of 842660.  That leaves 840184 unsaturated
# Filter f410m has qf=145647, spread=122710, fracflux=17852 ok, totaling 17526.  There are 842660 total, of which 733526 are masked and 109134 are unmasked. qfmasksum=696250, inverse=146410.
# Filter f212n has qf=522595, spread=524441, fracflux=333867 ok, totaling 333198.  There are 842660 total, of which 321104 are masked and 521556 are unmasked. qfmasksum=317238, inverse=525422.
# Filter f466n has qf=431154, spread=431500, fracflux=124144 ok, totaling 123977.  There are 842660 total, of which 411451 are masked and 431209 are unmasked. qfmasksum=411063, inverse=431597.
# Filter f405n has qf=471178, spread=467059, fracflux=88240 ok, totaling 88111.  There are 842660 total, of which 395754 are masked and 446906 are unmasked. qfmasksum=370991, inverse=471669.
# Filter f187n has qf=441352, spread=442707, fracflux=296723 ok, totaling 296082.  There are 842660 total, of which 399315 are masked and 443345 are unmasked. qfmasksum=399873, inverse=442787.
# Filter f182m has qf=641760, spread=376645, fracflux=127120 ok, totaling 89810.  There are 842660 total, of which 393198 are masked and 449462 are unmasked. qfmasksum=195272, inverse=647388.
# Of 842660 rows, 476 are good in all filters.
# Of 842660 rows, 2059 are good in long filters.
# Of 842660 rows, 26590 are good in short filters.
# Of 842660 rows, 492926 are good in at least one filter.
# QFs: 347668 good short
# QFs: 64733 good long
# Found 145997 of 842660 sources with separations < 0.1 arcsec
# Offset between raw ABmag for F410M-F466N = -3.100931445988974 - -3.40491784270845 = 0.303986396719476
# Strongly blue [410-466] sources: 26769
# Somewhat blue [410-466] sources: 15827
# 18318 26769 15827 1204 2388 0 44905 0.0
# Negative 405-410 colors: 64513, Nonnegative: 16256
# There are 294 before flagging out any_saturated (there are 43570 any_saturated)
# There are 277 after flagging out any_saturated
# There are 145997 out of 842660 oksep, and 230 all_good & oksep
# Excluding 825755 of 842660
# 'Bad' sources are those where _any_ filter is masked out
# Not-bad:230, bad: 842430, len(bad):842660, len(table):842660.
# Loaded merged

# %% [markdown]
# # Comparing Refcat and VVV

# %%
idx, sidx, sep, _ = crds_ref.search_around_sky(crds_vvv, 0.2*u.arcsec)
print(len(idx))
# Out:
# 2697

# %%
dra = (crds_ref[sidx].ra - crds_vvv[idx].ra).to(u.arcsec)
ddec = (crds_ref[sidx].dec - crds_vvv[idx].dec).to(u.arcsec)

# %%
plt.figure(dpi=200)
plt.quiver(crds_ref[sidx][dra>0].ra.value, crds_ref[sidx][dra>0].dec.value, dra.to(u.arcsec).value[dra>0], ddec.to(u.arcsec).value[dra>0])
plt.quiver(crds_ref[sidx][dra<0].ra.value, crds_ref[sidx][dra<0].dec.value, dra.to(u.arcsec).value[dra<0], ddec.to(u.arcsec).value[dra<0], color='r')

# %%
plt.hist(dra)
# Out:
# (array([ 25.,  61., 132., 230., 467., 717., 586., 306., 126.,  47.]),
#  array([-0.25179369, -0.20741922, -0.16304476, -0.1186703 , -0.07429583,
#         -0.02992137,  0.0144531 ,  0.05882756,  0.10320203,  0.14757649,
#          0.19195095]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ddec)
# Out:
# (array([ 33.,  81., 168., 296., 489., 567., 504., 335., 165.,  59.]),
#  array([-0.21429646, -0.17510035, -0.13590424, -0.09670813, -0.05751202,
#         -0.01831591,  0.0208802 ,  0.06007631,  0.09927242,  0.13846853,
#          0.17766464]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Basetable Comparisons with Refcoords

# %%
basetable.columns
# Out:
# <TableColumns names=('skycoord_ref','skycoord_ref_filtername','sep_f410m','id_f410m','skycoord_f410m','x_f410m','y_f410m','flux_f410m','passno_f410m','dx_f410m','dy_f410m','dflux_f410m','qf_f410m','rchi2_f410m','fracflux_f410m','fluxlbs_f410m','dfluxlbs_f410m','fwhm_f410m','spread_model_f410m','dspread_model_f410m','fluxiso_f410m','xiso_f410m','yiso_f410m','flags_f410m','sky_f410m','mask_f410m','flux_jy_f410m','eflux_jy_f410m','mag_ab_f410m','emag_ab_f410m','near_saturated_f410m_f410m','replaced_saturated_f410m','sep_f212n','id_f212n','skycoord_f212n','x_f212n','y_f212n','flux_f212n','passno_f212n','dx_f212n','dy_f212n','dflux_f212n','qf_f212n','rchi2_f212n','fracflux_f212n','fluxlbs_f212n','dfluxlbs_f212n','fwhm_f212n','spread_model_f212n','dspread_model_f212n','fluxiso_f212n','xiso_f212n','yiso_f212n','flags_f212n','sky_f212n','mask_f212n','flux_jy_f212n','eflux_jy_f212n','mag_ab_f212n','emag_ab_f212n','near_saturated_f212n_f212n','replaced_saturated_f212n','sep_f466n','id_f466n','skycoord_f466n','x_f466n','y_f466n','flux_f466n','passno_f466n','dx_f466n','dy_f466n','dflux_f466n','qf_f466n','rchi2_f466n','fracflux_f466n','fluxlbs_f466n','dfluxlbs_f466n','fwhm_f466n','spread_model_f466n','dspread_model_f466n','fluxiso_f466n','xiso_f466n','yiso_f466n','flags_f466n','sky_f466n','mask_f466n','flux_jy_f466n','eflux_jy_f466n','mag_ab_f466n','emag_ab_f466n','near_saturated_f466n_f466n','replaced_saturated_f466n','sep_f405n','id_f405n','skycoord_f405n','x_f405n','y_f405n','flux_f405n','passno_f405n','dx_f405n','dy_f405n','dflux_f405n','qf_f405n','rchi2_f405n','fracflux_f405n','fluxlbs_f405n','dfluxlbs_f405n','fwhm_f405n','spread_model_f405n','dspread_model_f405n','fluxiso_f405n','xiso_f405n','yiso_f405n','flags_f405n','sky_f405n','mask_f405n','flux_jy_f405n','eflux_jy_f405n','mag_ab_f405n','emag_ab_f405n','near_saturated_f405n_f405n','replaced_saturated_f405n','sep_f187n','id_f187n','skycoord_f187n','x_f187n','y_f187n','flux_f187n','passno_f187n','dx_f187n','dy_f187n','dflux_f187n','qf_f187n','rchi2_f187n','fracflux_f187n','fluxlbs_f187n','dfluxlbs_f187n','fwhm_f187n','spread_model_f187n','dspread_model_f187n','fluxiso_f187n','xiso_f187n','yiso_f187n','flags_f187n','sky_f187n','mask_f187n','flux_jy_f187n','eflux_jy_f187n','mag_ab_f187n','emag_ab_f187n','near_saturated_f187n_f187n','replaced_saturated_f187n','sep_f182m','id_f182m','skycoord_f182m','x_f182m','y_f182m','flux_f182m','passno_f182m','dx_f182m','dy_f182m','dflux_f182m','qf_f182m','rchi2_f182m','fracflux_f182m','fluxlbs_f182m','dfluxlbs_f182m','fwhm_f182m','spread_model_f182m','dspread_model_f182m','fluxiso_f182m','xiso_f182m','yiso_f182m','flags_f182m','sky_f182m','mask_f182m','flux_jy_f182m','eflux_jy_f182m','mag_ab_f182m','emag_ab_f182m','near_saturated_f182m_f182m','replaced_saturated_f182m','flux_jy_410m405','mag_ab_410m405','flux_jy_405m410','mag_ab_405m410','flux_jy_182m187','mag_ab_182m187','flux_jy_187m182','mag_ab_187m182','good_f410m','good_f212n','good_f466n','good_f405n','good_f187n','good_f182m')>

# %%
tbl_uses = basetable[basetable['good_f405n']]
quiv_x = tbl_uses['skycoord_ref'].ra
quiv_y = tbl_uses['skycoord_ref'].dec
quiv_u = quiv_x - tbl_uses['skycoord_f405n'].ra
quiv_v = quiv_x - tbl_uses['skycoord_f405n'].dec

#plt.quiver(crds_ref[sidx][dra>0].ra.value, crds_ref[sidx][dra>0].dec.value, dra.to(u.arcsec).value[dra>0], ddec.to(u.arcsec).value[dra>0])
#plt.quiver(crds_ref[sidx][dra<0].ra.value, crds_ref[sidx][dra<0].dec.value, dra.to(u.arcsec).value[dra<0], ddec.to(u.arcsec).value[dra<0], color='r')
plt.quiver(quiv_x[quiv_u>0].value, quiv_y[quiv_u>0].value, quiv_u.to(u.arcsec)[quiv_u>0].value, quiv_v.to(u.arcsec)[quiv_u>0].value)
plt.quiver(quiv_x[quiv_u<0].value, quiv_y[quiv_u<0].value, quiv_u.to(u.arcsec)[quiv_u<0].value, quiv_v.to(u.arcsec)[quiv_u<0].value, color='r')
